# %% [markdown]
# <div style="text-align: center;">
#
# # Employee Performance Analysis
#
# **Organization:** INX Future Inc.
#
# </div>

# %% [markdown]
# ## Data Overview:
#
# ### Dataset Description:
# The dataset used for this analysis comprises information about employee performance and various attributes related to their work environment, job roles, and personal demographics. The dataset includes **1,200 records** and **28 features**. The features are categorized as follows:
#
# - **Categorical Features**:
#   - `EmpNumber`: Unique identifier for each employee (object)
#   - `Gender`: Gender of the employee (object)
#   - `EducationBackground`: Educational background of the employee (object)
#   - `MaritalStatus`: Marital status of the employee (object)
#   - `EmpDepartment`: Department in which the employee works (object)
#   - `EmpJobRole`: Job role of the employee (object)
#   - `BusinessTravelFrequency`: Frequency of business travel (object)
#   - `OverTime`: Whether the employee works overtime (object)
#   - `Attrition`: Whether the employee has left the company (object)
#
# - **Numerical Features**:
#   - `Age`: Age of the employee (int64)
#   - `DistanceFromHome`: Distance between employee's home and workplace (int64)
#   - `EmpEducationLevel`: Education level of the employee (int64)
#   - `EmpEnvironmentSatisfaction`: Satisfaction with the work environment (int64)
#   - `EmpHourlyRate`: Hourly rate of pay (int64)
#   - `EmpJobInvolvement`: Involvement level in job (int64)
#   - `EmpJobLevel`: Job level of the employee (int64)
#   - `EmpJobSatisfaction`: Satisfaction with the job role (int64)
#   - `NumCompaniesWorked`: Number of companies the employee has worked for (int64)
#   - `EmpLastSalaryHikePercent`: Percentage of last salary hike (int64)
#   - `EmpRelationshipSatisfaction`: Satisfaction with work relationships (int64)
#   - `TotalWorkExperienceInYears`: Total work experience in years (int64)
#   - `TrainingTimesLastYear`: Number of training times last year (int64)
#   - `EmpWorkLifeBalance`: Work-life balance rating (int64)
#   - `ExperienceYearsAtThisCompany`: Years of experience at the current company (int64)
#   - `ExperienceYearsInCurrentRole`: Years of experience in the current role (int64)
#   - `YearsSinceLastPromotion`: Years since the last promotion (int64)
#   - `YearsWithCurrManager`: Years with the current manager (int64)
#   - `PerformanceRating`: Performance rating of the employee (int64)
#
# ### Data Source:
# The data is sourced from [INX Future Inc.] and includes a comprehensive set of features to evaluate employee performance and related factors.
#
# ### Data Quality:
# - **Missing Values**: No missing values are present in the dataset.
# - **Data Types**: The dataset consists of both categorical and numerical features, as detailed above.
#
# This overview provides a snapshot of the dataset's structure and features, which will be analyzed in subsequent sections to gain insights into employee performance.

# %% [markdown]
# ##### 1. Download and Load the Dataset:

# %%
import pandas as pd

# Load the dataset.
url = 'http://data.iabac.org/exam/p2/data/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls'
df = pd.read_excel(url)

# %%
# Display the first few rows.
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %% [markdown]
# ##### 2. Data Exploration and Cleaning:

# %%
# Check data types and basic information.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %%
# Descriptive statistics to understand data distribution.
df.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %%
# Checking for missing values.
df.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %%
df.dtypes
# Out:
# EmpNumber                       object
# Age                              int64
# Gender                          object
# EducationBackground             object
# MaritalStatus                   object
# EmpDepartment                   object
# EmpJobRole                      object
# BusinessTravelFrequency         object
# DistanceFromHome                 int64
# EmpEducationLevel                int64
# EmpEnvironmentSatisfaction       int64
# EmpHourlyRate                    int64
# EmpJobInvolvement                int64
# EmpJobLevel                      int64
# EmpJobSatisfaction               int64
# NumCompaniesWorked               int64
# OverTime                        object
# EmpLastSalaryHikePercent         int64
# EmpRelationshipSatisfaction      int64
# TotalWorkExperienceInYears       int64
# TrainingTimesLastYear            int64
# EmpWorkLifeBalance               int64
# ExperienceYearsAtThisCompany     int64
# ExperienceYearsInCurrentRole     int64
# ...

# %% [markdown]
# ##### 3. Exploratory Data Analysis (EDA):
# - Department-wise Performance Analysis.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Countplot of performance ratings per department.
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='EmpDepartment', hue='PerformanceRating', palette='Set2')
plt.title('Department-wise Performance Rating Distribution')
plt.xlabel('Department')
plt.ylabel('Count of Employees')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - ***What it does:*** This plot displays how employee performance ratings (ranging from 1 to 4) are spread across different departments in the company.
#
# - ***How to read it:*** Each department is represented by several bars, one for each performance rating. The height of the bars shows how many employees in that department received a particular rating. Higher bars indicate more employees with that rating.
#
# - ***Insights:***
#
# - You can quickly see which departments have a larger number of high-performing employees (ratings 3 or 4) versus those with more low-performing employees (ratings 1 or 2).
# - If a department has a significant number of employees with low performance ratings, it may signal a need for management attention or further analysis to address potential issues affecting productivity.

# %%
# Calculate the average performance rating per department.
avg_performance = df.groupby('EmpDepartment')['PerformanceRating'].mean().sort_values(ascending=False)

# Plot average performance rating.
plt.figure(figsize=(10,6))
avg_performance.plot(kind='bar', color='skyblue')
plt.title('Average Performance Rating by Department')
plt.xlabel('Department')
plt.ylabel('Average Performance Rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - ***What it does:*** This plot highlights the average performance rating for employees within each department.
#
# - ***How to read it:*** Each bar corresponds to a specific department, and the height of the bar reflects the average performance rating (on a scale from 1 to 4). Taller bars indicate higher average ratings, meaning better overall performance in that department.
#
# - ***Insights:***
#
# - Departments with higher average performance ratings (closer to 4) are performing well and likely have motivated and productive teams.
# - Lower average ratings may signal departments that are facing challenges, such as low morale, lack of resources, or training gaps, and may require management intervention to improve performance.

# %%
# Barplot of performance ratings per department.
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='EmpDepartment', y='PerformanceRating', palette='Set3', ci=None)
plt.title('Performance Rating Distribution by Department')
plt.xlabel('Department')
plt.ylabel('Performance Rating')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\carrefour\AppData\Local\Temp\ipykernel_5716\3555809000.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='EmpDepartment', y='PerformanceRating', palette='Set3', ci=None)
# C:\Users\carrefour\AppData\Local\Temp\ipykernel_5716\3555809000.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='EmpDepartment', y='PerformanceRating', palette='Set3', ci=None)

# %% [markdown]
# - ***What it does:*** This bar plot shows how employee performance ratings are distributed within each department.
#
# - ***How to read it:*** The bar itself represents the middle 50% of performance ratings, with the line inside showing the median rating (the value right in the middle). The "whiskers" extend to show the overall spread of ratings, while any dots outside the whiskers indicate outliers—employees whose ratings are significantly different from the rest.
#
# - ***Insights:***
# - Departments with shorter boxes have less variation in employee performance, meaning their employees tend to perform consistently.
# - Longer boxes indicate more variation in performance, which could point to inconsistencies in employee productivity or challenges that affect performance unevenly across the department.

# %%
# Attrition rate by department.
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='EmpDepartment', hue='Attrition', palette='Set2')
plt.title('Attrition Rate by Department')
plt.xlabel('Department')
plt.ylabel('Count of Employees')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - ***What it does:*** This plot shows how many employees have left each department (Attrition = "Yes") compared to those who have stayed (Attrition = "No").
#
# - ***How to read it:*** Each department has two bars—one for employees who have stayed and one for those who have left. A higher "Yes" bar means more people are leaving that department.
#
# - ***Insights:***
#
# - Departments with a higher number of employees leaving could be facing issues like low job satisfaction, poor management, or lack of growth opportunities.
# - Pinpointing these departments helps focus on improving employee retention, potentially through better support, resources, or engagement strategies.

# %%
# Performance rating by overtime status.
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='OverTime', y='PerformanceRating', palette='Set2', ci=None)
plt.title('Performance Rating vs OverTime')
plt.xlabel('OverTime')
plt.ylabel('Average Performance Rating')
plt.show()
# Out:
# C:\Users\carrefour\AppData\Local\Temp\ipykernel_5716\2157733484.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='OverTime', y='PerformanceRating', palette='Set2', ci=None)
# C:\Users\carrefour\AppData\Local\Temp\ipykernel_5716\2157733484.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='OverTime', y='PerformanceRating', palette='Set2', ci=None)

# %% [markdown]
# - ***What it does:*** This plot compares the average performance rating of employees who work overtime (OverTime = "Yes") with those who don’t (OverTime = "No").
#
# - ***How to read it:*** Each bar shows the average performance score for both groups. A higher bar for "Yes" means employees who work overtime have better performance on average, while a lower bar indicates the opposite.
#
# - ***Insights:***
#
# - If the performance of employees who work overtime is lower, it may suggest that extra hours are leading to burnout or reduced efficiency.
# - On the other hand, if their performance is higher, it could indicate that overtime is helping employees stay on top of their tasks or that more productive employees tend to work longer hours.

# %%
# Boxplot of performance ratings by job role.
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x='EmpJobRole', y='PerformanceRating', palette='Set3')
plt.title('Performance Rating by Job Role')
plt.xlabel('Job Role')
plt.ylabel('Performance Rating')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\carrefour\AppData\Local\Temp\ipykernel_5716\2389399800.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='EmpJobRole', y='PerformanceRating', palette='Set3')

# %% [markdown]
# - ***What it does:*** This box plot shows how the performance ratings are distributed across various job roles within the company.
#
# - ***How to read it:*** Each box represents the range of performance ratings for a particular job role. The line inside the box indicates the median rating, while the "whiskers" show the overall spread of ratings. Outliers (dots outside the whiskers) indicate employees whose performance significantly deviates from the norm.
#
# - ***Insights:***
#
# - Job roles with narrow boxes and a higher median suggest consistent and strong performance.
# - Roles with wider boxes or lower medians may have more variability in performance, pointing to possible challenges or inconsistencies in employee output.

# %%
# Scatter plot of total work experience vs performance rating.
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='TotalWorkExperienceInYears', y='PerformanceRating', hue='EmpDepartment', palette='Set1')
plt.title('Total Work Experience vs Performance Rating')
plt.xlabel('Total Work Experience (Years)')
plt.ylabel('Performance Rating')
plt.show()

# %% [markdown]
# - ***What it does:*** This plot shows the relationship between employees' total work experience and their performance ratings, with different colors representing various departments.
#
# - ***How to read it:*** Each point represents an employee, with their total work experience on the x-axis and their performance rating on the y-axis. The color indicates the department they belong to. You can look for patterns, like whether employees with more experience tend to have higher or lower performance ratings.
#
# - ***Insights:***
#
# - If the plot shows that employees with more experience tend to have higher performance ratings, it suggests that retaining and investing in experienced staff is beneficial.
# - If the opposite is true, it might indicate that employees become less effective over time, possibly due to burnout or outdated skills, highlighting a need for training or other support.

# %% [markdown]
# ##### 4. Feature Importance Analysis:

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR

# %%
# Convert categorical variables to numerical values using one-hot encoding.
df_encoded = pd.get_dummies(df, drop_first=True)

# %%
# Define features and target.
X = df_encoded.drop('PerformanceRating', axis=1)
y = df_encoded['PerformanceRating']

# %%
# Split the data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Train a Random Forest model to get feature importance.
model = RandomForestRegressor(n_estimators=100, random_state=0)
model.fit(X, y)
# Out:
# RandomForestRegressor(random_state=0)

# %%
# Get feature importance.
importance = model.feature_importances_

# Create a DataFrame for features and their importance.
features = X.columns
importance_df = pd.DataFrame({'Feature': features, 'Importance': importance})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# %%
# Display the top 3 features.
print("Top 3 Features Affecting Performance:")
print(importance_df.head(3))

# Plot the feature importances.
plt.figure(figsize=(12, 8))
plt.barh(importance_df['Feature'][:3], importance_df['Importance'][:3], color='skyblue')
plt.xlabel('Importance')
plt.title('Top 3 Factors Affecting Employee Performance')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Top 3 Features Affecting Performance:
#                        Feature  Importance
# 9     EmpLastSalaryHikePercent    0.229575
# 3   EmpEnvironmentSatisfaction    0.215990
# 16     YearsSinceLastPromotion    0.188518

# %% [markdown]
# ##### 5. Predictive Modeling:

# %%
# Initialize models.
models = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(n_estimators=100, random_state=0),
    'Gradient Boosting': GradientBoostingRegressor(n_estimators=100, random_state=0),
    'Support Vector Regressor': SVR(kernel='rbf')
}

# %%
# Train models and evaluate.
results = {}
for name, model in models.items():
    # Train the model.
    model.fit(X_train, y_train)
    
    # Make predictions.
    y_pred = model.predict(X_test)
    
    # Evaluate the model.
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    results[name] = {'MAE': mae, 'R2': r2}

# %%
# Display the results.
results_df = pd.DataFrame(results).T
print("Model Performance:")
print(results_df)

# Plot model performance.
results_df[['MAE', 'R2']].plot(kind='bar', figsize=(14, 7))
plt.title('Model Performance Comparison')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()
# Out:
# Model Performance:
#                                MAE        R2
# Linear Regression         0.319605  0.306543
# Random Forest             0.057292  0.856698
# Gradient Boosting         0.124565  0.788460
# Support Vector Regressor  0.279795  0.134942

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %%
# Encode categorical variables.
df_encoded = pd.get_dummies(df, drop_first=True)

# Convert the target variable to a classification problem.
# Assuming PerformanceRating > 3 is considered high, otherwise low.
df_encoded['PerformanceRating'] = df_encoded['PerformanceRating'].apply(lambda x: 1 if x > 3 else 0)

# %%
# Define features and target.
X = df_encoded.drop('PerformanceRating', axis=1)
y = df_encoded['PerformanceRating']

# Split the data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Initialize models.
models = {
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=0),
    'Gradient Boosting': GradientBoostingClassifier(n_estimators=100, random_state=0),
    'Support Vector Classifier': SVC()
}

# %%
# Train models and evaluate.
results = {}
for name, model in models.items():
    # Train the model.
    model.fit(X_train, y_train)
    
    # Make predictions.
    y_pred = model.predict(X_test)
    
    # Evaluate the model.
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    results[name] = {'Accuracy': accuracy, 'Precision': precision, 'Recall': recall, 'F1 Score': f1}
# Out:
# c:\Users\carrefour\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\carrefour\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Display the results.
results_df = pd.DataFrame(results).T
print("Model Performance:")
print(results_df)

# Plot model performance.
results_df[['Accuracy', 'Precision', 'Recall', 'F1 Score']].plot(kind='bar', figsize=(14, 7))
plt.title('Model Performance Comparison')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()
# Out:
# Model Performance:
#                            Accuracy  Precision    Recall  F1 Score
# Logistic Regression        0.879167   0.478261  0.392857  0.431373
# Random Forest              0.887500   1.000000  0.035714  0.068966
# Gradient Boosting          0.979167   0.925926  0.892857  0.909091
# Support Vector Classifier  0.883333   0.000000  0.000000  0.000000

# %% [markdown]
# ## Key Recommendations:
#
# 1. **Improve Job Satisfaction and Work Environment**:
#    - **Action**: Conduct surveys to understand employee satisfaction levels and address concerns.
#    - **Reason**: Higher job satisfaction is linked to better performance and reduced attrition.
#
# 2. **Optimize Work-Life Balance**:
#    - **Action**: Implement flexible work hours and remote work options where possible.
#    - **Reason**: A better work-life balance can enhance employee well-being and productivity.
#
# 3. **Review Overtime Policies**:
#    - **Action**: Analyze overtime trends and adjust policies to prevent burnout.
#    - **Reason**: Excessive overtime can lead to decreased performance and job dissatisfaction.
#
# 4. **Address High Attrition Rates**:
#    - **Action**: Analyze reasons for attrition and develop strategies to improve employee retention.
#    - **Reason**: Reducing attrition can save costs on hiring and training new employees.
#
# 5. **Invest in Employee Training and Development**:
#    - **Action**: Offer training programs and career development opportunities.
#    - **Reason**: Continuous learning and skill development contribute to better performance and employee engagement.
#
# 6. **Foster a Supportive Organizational Culture**:
#    - **Action**: Promote a positive work environment and support team-building activities.
#    - **Reason**: A supportive culture enhances job satisfaction and encourages high performance.
#
# ### Action Plan.
# - **Short-term Actions**: Address immediate concerns related to job satisfaction and overtime policies.
# - **Medium-term Actions**: Develop and implement training programs and review attrition rates.
# - **Long-term Actions**: Foster a positive organizational culture and continuously monitor employee satisfaction.
#
# Implementing these recommendations can lead to improved employee performance and overall organizational success.

# %% [markdown]
# ## **Conclusion:**
#
# ### ***Summary of Findings:***
# - **Performance Insights**: The analysis revealed key factors affecting employee performance, including job satisfaction, work environment, and overtime. Departments and roles with higher satisfaction levels generally showed better performance ratings.
# - **Top Influences**: Job satisfaction, work-life balance, and environment satisfaction were identified as significant drivers of performance. Departments with effective management of these factors tended to have higher performance ratings and lower attrition rates.
#
# ### ***Impact:***
# - **Improved Performance**: Implementing the recommendations can lead to enhanced employee performance, reduced attrition, and a more positive work environment.
# - **Organizational Success**: Addressing key issues and adopting best practices will contribute to a more efficient and motivated workforce, ultimately benefiting the organization’s overall success.
#
# By focusing on these areas, INX Future Inc. can make informed decisions to improve employee satisfaction and performance, leading to a more productive and engaged workforce.

# %% [markdown]
# ## **References:**
#
# ### **Data Sources:**
# - ***Employee Performance Data***: Data provided by **INX Future Inc**.
#
# ### **Tools and Libraries:**
# - ***Python***: Programming language used for analysis.
# - ***Pandas***: Data manipulation and analysis library.
# - ***NumPy***: Library for numerical operations.
# - ***Matplotlib***: Library for creating visualizations.
# - ***Seaborn***: Statistical data visualization library.
# - ***Scikit-learn***: Machine learning library for modeling and evaluation.
#
# ### **Additional Resources:**
# - ***Scikit-learn Documentation***: [Scikit-learn Documentation](https://scikit-learn.org/stable/documentation.html)
# - ***Pandas Documentation***: [Pandas Documentation](https://pandas.pydata.org/pandas-docs/stable/)
# - ***Matplotlib Documentation***: [Matplotlib Documentation](https://matplotlib.org/stable/contents.html)
# - ***Seaborn Documentation***: [Seaborn Documentation](https://seaborn.pydata.org/)
